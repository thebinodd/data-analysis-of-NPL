# %%
import pandas as pd

# %%
npl_2024 = pd.read_csv(".././Datasets/NPL-2024.csv")
npl_2025 = pd.read_csv(".././Datasets/NPL-2025.csv")

# %%
npl_2024.columns.tolist()
# Out:
# ['match_id',
#  'inning',
#  'batting_team',
#  'bowling_team',
#  'ball_over',
#  'ball_result',
#  'bowler',
#  'batsman',
#  'non_striker',
#  'shot_direction',
#  'player_dismissed',
#  'dismissal_kind',
#  'fielder',
#  'batsman_runs',
#  'wide_runs',
#  'bye_runs',
#  'legbye_runs',
#  'noball_runs',
#  'extra_runs',
#  'total_runs']

# %%
#Making Same Columns Names
npl_2025.rename(columns={
    "match_no":"match_id",
    "batter":"batsman",
    "player_out":"player_dismissed",
    "fielders":"fielder",
    "match_no":"match_id",
    "match_no":"match_id",
} , inplace=True)

# %%
npl_2024.columns.tolist()
npl_2025.columns.tolist()
# Out:
# ['match_id',
#  'inning',
#  'batting_team',
#  'bowling_team',
#  'ball_over',
#  'ball_result',
#  'bowler',
#  'batsman',
#  'non_striker',
#  'shot_direction',
#  'player_dismissed',
#  'dismissal_kind',
#  'fielder',
#  'batsman_runs',
#  'wide_runs',
#  'bye_runs',
#  'legbye_runs',
#  'noball_runs',
#  'extra_runs',
#  'total_runs']

# %%
npl_dataset = pd.concat([npl_2024, npl_2025], ignore_index=True)
npl_dataset.head(5)
# Out:
#    match_id  inning      batting_team    bowling_team  ball_over ball_result  \
# 0         1       1  Biratnagar Kings  Janakpur Bolts        0.1           0
# 1         1       1  Biratnagar Kings  Janakpur Bolts        0.2           4
# 2         1       1  Biratnagar Kings  Janakpur Bolts        0.3           0
# 3         1       1  Biratnagar Kings  Janakpur Bolts        0.4          1w
# 4         1       1  Biratnagar Kings  Janakpur Bolts        0.4           0
#
#            bowler     batsman     non_striker shot_direction player_dismissed  \
# 0  Kishore Mahato  Lokesh Bam  Martin Guptill            NaN              NaN
# 1  Kishore Mahato  Lokesh Bam  Martin Guptill      third man              NaN
# 2  Kishore Mahato  Lokesh Bam  Martin Guptill            NaN              NaN
# 3  Kishore Mahato  Lokesh Bam  Martin Guptill            NaN              NaN
# 4  Kishore Mahato  Lokesh Bam  Martin Guptill            NaN              NaN
#
#   dismissal_kind fielder  batsman_runs  wide_runs  bye_runs  legbye_runs  \
# 0            NaN     NaN             0          0         0            0
# 1            NaN     NaN             4          0         0            0
# 2            NaN     NaN             0          0         0            0
# 3            NaN     NaN             0          1         0            0
# 4            NaN     NaN             0          0         0            0
#
#    noball_runs  extra_runs  total_runs
# 0            0           0           0
# 1            0           0           4
# 2            0           0           0
# 3            0           1           1
# 4            0           0           0

# %%
npl_dataset.to_csv("../Datasets/npl_dataset.csv" , index=False)
